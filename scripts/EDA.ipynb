# %% [markdown]
# # Analysis
#
# https://public.tableau.com/newWorkbook/e237fdae-c3b7-4cf5-8b76-81c92a25a228#2

# %%
# read df
import pandas as pd

df = pd.read_csv('../data/products_complete_info.csv')
df.head()
# Out:
#                        name                                            url  \
# 0  Migros Bio · blueberries  https://www.migros.ch/en/product/265680802400
# 1                     Dates  https://www.migros.ch/en/product/264601302100
# 2                   Avocado  https://www.migros.ch/en/product/264500313200
# 3   Bio Fairtrade · Bananas  https://www.migros.ch/en/product/264280101000
# 4      Migros Bio · Avocado  https://www.migros.ch/en/product/264580113200
#
#             category sub_category  total_price  price_per_unit price_unit  \
# 0  fruits-vegetables       fruits         7.90            3.16       100g
# 1  fruits-vegetables       fruits         5.95            2.98       100g
# 2  fruits-vegetables       fruits         2.80            2.80      Piece
# 3  fruits-vegetables       fruits         2.95            0.30       100g
# 4  fruits-vegetables       fruits         2.80            2.80      Piece
#
# ...

# %%
len(df)
# Out:
# 9545

# %%
# item with max price

df["name"][df['total_price'].argmax()]
# Out:
# 'CoffeeB By Café Royal · Machine for CoffeeB balls · Black - A+'

# %%
# sort by price_per_unit and display top 10

df.sort_values(by='price_per_unit', ascending=False).head(10)
# Out:
#                                                   name  \
# 3750               Migros Bio · hemp oil, cold pressed
# 4026  Da Emilio · Virgin olive oil · al tartufo bianco
# 4130                               Bio Safran Leprotto
# 4214                  Sélection · filaments of saffron
# 3629                     Migros Bio · Saffron · ground
# 3553          M-Classic · saffron · 4 sachets of 125mg
# 4163                             GSB Bio Trio für Käse
# 4194                Swiss Alpine Herbs Bio Alpenblüten
# 2422               Alnatura · bourbon vanilla · ground
# 2421                     Alnatura · Gousses de vanille
#
#                                                 url  \
# 3750  https://www.migros.ch/en/product/103389300000
# 4026  https://www.migros.ch/en/product/103389400000
# 4130  https://www.migros.ch/en/product/106206800000
# 4214  https://www.migros.ch/en/product/106206400000
# 3629  https://www.migros.ch/en/product/106211800000
# ...
